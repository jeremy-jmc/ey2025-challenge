# %%
import sys
sys.path.append('..')

import yaml
from baseline.utilities import *

np.set_printoptions(suppress=True)

TARGET = 'UHI Index'

train_new = pd.read_parquet('../pipeline/data/processed/train/train_data.parquet')

feature_list = [c for c in yaml.safe_load(open('../pipeline/data/columns.yml', 'r'))['features'] if c not in [
    "bearing_bronx", "bearing_manhattan", 
    "wind_influence_15:00:00_bronx", "wind_influence_15:05:00_bronx", "wind_influence_15:10:00_bronx", "wind_influence_15:15:00_bronx", "wind_influence_15:20:00_bronx", "wind_influence_15:25:00_bronx", "wind_influence_15:30:00_bronx", "wind_influence_15:35:00_bronx", "wind_influence_15:40:00_bronx", "wind_influence_15:45:00_bronx", "wind_influence_15:50:00_bronx", "wind_influence_15:55:00_bronx", "wind_influence_16:00:00_bronx", "wind_influence_15:00:00_manhattan", "wind_influence_15:05:00_manhattan", "wind_influence_15:10:00_manhattan", "wind_influence_15:15:00_manhattan", "wind_influence_15:20:00_manhattan", "wind_influence_15:25:00_manhattan", "wind_influence_15:30:00_manhattan", "wind_influence_15:35:00_manhattan", "wind_influence_15:40:00_manhattan", "wind_influence_15:45:00_manhattan", "wind_influence_15:50:00_manhattan", "wind_influence_15:55:00_manhattan", "wind_influence_16:00:00_manhattan", 
    "pct_change_wind_influence_15:05:00_bronx", "pct_change_wind_influence_15:10:00_bronx", "pct_change_wind_influence_15:15:00_bronx", "pct_change_wind_influence_15:20:00_bronx", "pct_change_wind_influence_15:25:00_bronx", "pct_change_wind_influence_15:30:00_bronx", "pct_change_wind_influence_15:35:00_bronx", "pct_change_wind_influence_15:40:00_bronx", "pct_change_wind_influence_15:45:00_bronx", "pct_change_wind_influence_15:50:00_bronx", "pct_change_wind_influence_15:55:00_bronx", "pct_change_wind_influence_16:00:00_bronx", "pct_change_wind_influence_15:05:00_manhattan", "pct_change_wind_influence_15:10:00_manhattan", "pct_change_wind_influence_15:15:00_manhattan", "pct_change_wind_influence_15:20:00_manhattan", "pct_change_wind_influence_15:25:00_manhattan", "pct_change_wind_influence_15:30:00_manhattan", "pct_change_wind_influence_15:35:00_manhattan", "pct_change_wind_influence_15:40:00_manhattan", "pct_change_wind_influence_15:45:00_manhattan", "pct_change_wind_influence_15:50:00_manhattan", "pct_change_wind_influence_15:55:00_manhattan", "pct_change_wind_influence_16:00:00_manhattan"
]]

X = train_new.drop(columns=['Longitude', 'Latitude', 'datetime', TARGET])[feature_list]
y = train_new[TARGET]

print(f"Original column length -> {len(X.columns)=}")
# Out:
# Original column length -> len(X.columns)=1030

# %%
# -----------------------------------------------------------------------------
# Drop columns with 0 correlation with the target
# -----------------------------------------------------------------------------

correlations = train_new[feature_list + [TARGET]].corr()

correlations = correlations[TARGET].sort_values(ascending=False)

threshold = 0.05
columns_to_keep = correlations[abs(correlations) >= threshold].index

X = train_new[columns_to_keep].drop(columns=TARGET)
y = train_new[TARGET]
print(f"After correlation threshold removal -> {len(X.columns)=}")
# Out:
# After correlation threshold removal -> len(X.columns)=950

# %%
# -----------------------------------------------------------------------------
# Collinearity problem
# -----------------------------------------------------------------------------
from scipy.stats import pearsonr
import numpy as np

corr_matrix = X.corr().abs()

upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

to_drop = [column for column in upper.columns if any(upper[column] > 0.9)]
print(f"{to_drop=}")

X = X.drop(columns=to_drop)
print(f"After collinearity removal -> {len(X.columns)=}")
for col in X.columns:
    print(f"- {col}")
# Out:
# to_drop=['sntnl_buffer_band_5_900_std', 'sntnl_buffer_band_7_600_mean', 'sntnl_buffer_band_6_700_mean', 'sntnl_buffer_band_5_800_std', 'sntnl_buffer_band_6_800_mean', 'sntnl_buffer_band_6_900_mean', 'lndst_mean_lwir11_350m', 'lndst_mean_lwir11_300m', 'lndst_mean_lwir11_250m', 'lndst_mean_lwir11_400m', 'lndst_mean_lwir11_450m', 'lndst_mean_lwir11_500m', 'sntnl_buffer_band_6_1000_mean', 'lndst_mean_lwir11_600m', 'lndst_mean_lwir11_200m', 'sntnl_buffer_band_7_700_mean', 'lndst_mean_lwir11_700m', 'sntnl_buffer_band_5_700_std', 'sntnl_buffer_band_7_500_mean', 'sntnl_buffer_band_6_500_mean', 'sntnl_buffer_band_7_800_mean', 'lndst_mean_lwir11_150m', 'lndst_mean_lwir11_800m', 'sntnl_buffer_band_5_600_std', 'sntnl_buffer_band_2_1000_mean', 'sntnl_buffer_band_7_900_mean', 'sntnl_buffer_band_2_900_mean', 'sntnl_buffer_band_7_450_mean', 'sntnl_buffer_band_2_800_mean', 'sntnl_buffer_band_6_450_mean', 'sntnl_buffer_band_2_700_mean', 'sntnl_buffer_band_5_1000_mean', 'sntnl_buffer_band_2_600_mean', 'lndst_mean_lwir11_100m', 'sntnl_buffer_band_5_900_mean', 'sntnl_buffer_band_5_600_mean', 'sntnl_buffer_band_5_800_mean', 'sntnl_buffer_band_5_700_mean', 'sntnl_buffer_band_7_1000_mean', 'sntnl_buffer_band_7_400_mean', 'lndst_mean_lwir11_900m', 'sntnl_buffer_band_1_1000_mean', 'sntnl_buffer_band_6_400_mean', 'sntnl_buffer_band_2_500_mean', 'sntnl_buffer_band_6_1000_std', 'sntnl_buffer_band_11_600_mean', 'sntnl_buffer_band_7_350_mean', 'sntnl_buffer_band_5_500_std', 'sntnl_buffer_band_5_500_mean', 'sntnl_buffer_band_1_900_mean', 'lndst_mean_lwir11_50m', 'sntnl_buffer_band_1_800_mean', 'sntnl_buffer_band_11_700_mean', 'sntnl_buffer_band_1_700_mean', 'sntnl_buffer_band_6_350_mean', 'sntnl_buffer_band_1_600_mean', 'sntnl_buffer_band_11_500_mean', 'sntnl_buffer_band_6_900_std', 'sntnl_buffer_band_7_300_mean', 'sntnl_buffer_band_2_450_mean', 'sntnl_buffer_band_11_800_mean', 'sntnl_buffer_band_5_450_mean', 'lndst_lwir_point', 'sntnl_buffer_band_5_450_std', 'sntnl_buffer_band_11_450_mean', 'sntnl_buffer_band_6_800_std', 'sntnl_buffer_band_1_500_mean', 'sntnl_buffer_band_6_300_mean', 'sntnl_buffer_band_7_275_mean', 'sntnl_buffer_band_11_900_mean', 'sntnl_buffer_band_11_400_mean', 'sntnl_buffer_band_6_700_std', 'sntnl_buffer_band_6_600_std', 'sntnl_buffer_band_2_400_mean', 'sntnl_buffer_band_5_400_mean', 'sntnl_buffer_band_11_350_mean', 'sntnl_buffer_band_1_450_mean', 'sntnl_buffer_band_6_275_mean', 'sntnl_buffer_band_5_400_std', 'sntnl_buffer_band_11_1000_mean', 'sntnl_buffer_band_11_300_mean', 'sntnl_buffer_band_5_350_mean', 'sntnl_buffer_band_2_350_mean', 'lndst_mean_lwir11_1000m', 'sntnl_buffer_band_7_250_mean', 'sntnl_buffer_band_1_400_mean', 'sntnl_buffer_band_11_275_mean', 'sntnl_buffer_band_6_500_std', 'sntnl_mean_nbi_1000m', 'sntnl_buffer_band_6_250_mean', 'sntnl_buffer_band_5_300_mean', 'sntnl_buffer_band_2_300_mean', 'sntnl_buffer_band_1_350_mean', 'sntnl_mean_nbi_900m', 'sntnl_mean_nbi_600m', 'sntnl_buffer_band_5_350_std', 'sntnl_mean_nbi_800m', 'sntnl_buffer_band_6_450_std', 'sntnl_mean_nbi_700m', 'sntnl_buffer_band_10_600_mean', 'sntnl_buffer_band_11_250_mean', 'sntnl_buffer_band_5_275_mean', 'sntnl_buffer_band_2_275_mean', 'sntnl_mean_nbi_500m', 'sntnl_mean_nbi_450m', 'sntnl_buffer_band_10_700_mean', 'sntnl_buffer_band_1_300_mean', 'sntnl_buffer_band_10_500_mean', 'sntnl_buffer_band_2_250_mean', 'sntnl_buffer_band_5_250_mean', 'sntnl_buffer_band_6_400_std', 'sntnl_mean_nbi_400m', 'sntnl_buffer_band_1_275_mean', 'sntnl_buffer_band_10_800_mean', 'sntnl_mean_nbi_350m', 'sntnl_buffer_band_10_450_mean', 'sntnl_buffer_band_2_1000_std', 'sntnl_buffer_band_5_300_std', 'sntnl_buffer_band_1_250_mean', 'sntnl_buffer_band_7_200_mean', 'sntnl_buffer_band_2_600_std', 'sntnl_buffer_band_6_200_mean', 'sntnl_buffer_band_2_900_std', 'sntnl_mean_nbi_300m', 'sntnl_buffer_band_10_900_mean', 'sntnl_buffer_band_6_350_std', 'sntnl_buffer_band_10_400_mean', 'sntnl_buffer_band_2_800_std', 'sntnl_buffer_band_2_700_std', 'sntnl_buffer_band_10_350_mean', 'sntnl_mean_nbi_2 ...
# After collinearity removal -> len(X.columns)=142
# - sntnl_buffer_band_5_1000_std
# - sntnl_buffer_band_6_600_mean
# - lndst_mean_lwir11_275m
# - sntnl_std_nbi_450m
# - kml_count_buildings_1000m
# - sntnl_mean_nbai_250m
# - sntnl_mean_nbai_1000m
# - sntnl_buffer_band_3_900_mean
# - NBAI
# - sntnl_buffer_band_5_100_std
# - NDBI
# - sntnl_buffer_band_11_250_std
# - kml_std_grnd_elev_400m
# - sntnl_mean_brba_100m
# - sntnl_std_nbi_100m
# - MBI
# - NBI
# - sntnl_mean_brba_50m
# - kml_std_grnd_elev_150m
# - sntnl_mean_brba_150m
# - sntnl_buffer_band_6_50_std
# - sntnl_buffer_band_10_200_std
# - sntnl_buffer_band_10_100_std
# - kml_count_buildings_100m
# - sntnl_buffer_band_11_50_std
# - BAEI
# - sntnl_buffer_band_10_50_std
# - B12
# - kml_std_grnd_elev_100m
# - sntnl_buffer_band_1_350_std
# - kml_count_buildings_50m
# - B04
# - kml_std_grnd_elev_50m
# - B05
# - B11
# - sntnl_buffer_band_3_100_std
# - sntnl_buffer_band_3_50_std
# - BRBA
# - kml_min_height_roof_1000m
# - sntnl_buffer_band_1_50_std
# - kml_max_areas_275m
# - kml_max_areas_100m
# - sntnl_buffer_band_3_275_std
# - sntnl_buffer_band_3_50_mean
# - sntnl_buffer_band_10_900_std
# - kml_max_areas_150m
# - kml_max_grnd_elev_100m
# - sntnl_buffer_band_9_100_std
# - kml_max_areas_200m
# - sntnl_std_brba_150m
# - kml_max_height_per_squared_meter_100m
# - kml_max_height_per_squared_meter_150m
# - kml_sum_areas_300m
# - kml_std_height_per_squared_meter_350m
# - lndst_std_lwir11_50m
# - sntnl_mean_brba_400m
# - kml_max_height_per_squared_meter_50m
# - kml_sum_areas_100m
# - sntnl_buffer_band_8_150_std
# - kml_min_areas_900m
# - kml_sum_areas_50m
# - kml_sum_areas_200m
# - kml_max_areas_50m
# - kml_max_height_per_squared_meter_200m
# - kml_min_height_roof_600m
# - lndst_std_lwir11_100m
# - kml_min_areas_800m
# - kml_sum_areas_150m
# - B06
# - sntnl_std_brba_300m
# - kml_mean_height_per_squared_meter_100m
# - kml_min_areas_1000m
# - sntnl_mean_brba_1000m
# - kml_mean_height_per_squared_meter_50m
# - sntnl_std_brba_350m
# - kml_mean_grnd_elev_700m
# - kml_min_areas_700m
# - kml_std_height_per_squared_meter_900m
# - kml_total_building_volume_50m
# - kml_min_height_roof_500m
# - kml_std_height_roof_50m
# - B08
# - kml_min_height_roof_450m
# - kml_min_height_roof_400m
# - lndst_std_lwir11_1000m
# - sntnl_std_ui_50m
# - kml_min_areas_600m
# - sntnl_std_nbai_50m
# - sntnl_std_nbai_150m
# - kml_min_height_per_squared_meter_50m
# - kml_mean_areas_100m
# - kml_total_building_volume_100m
# - kml_min_areas_350m
# - sntnl_std_ndvi_150m
# - sntnl_std_baei_100m
# - kml_min_areas_400m
# - sntnl_std_baei_50m
# - kml_min_areas_300m
# - kml_std_height_roof_100m
# - kml_min_height_roof_275m
# - kml_min_areas_275m
# - sntnl_std_ndbi_100m
# - kml_min_areas_100m
# - sntnl_std_gndbi_50m
# - kml_min_height_roof_100m
# - kml_total_building_volume_150m
# - kml_min_height_roof_250m
# - kml_min_areas_500m
# - kml_min_height_roof_350m
# - kml_min_grnd_elev_1000m
# - kml_min_areas_250m
# - kml_min_height_per_squared_meter_1000m
# - kml_min_height_per_squared_meter_600m
# - kml_min_height_per_squared_meter_100m
# - kml_min_height_roof_300m
# - kml_min_areas_450m
# - kml_min_height_roof_50m
# - kml_max_height_per_squared_meter_900m
# - kml_min_height_roof_200m
# - kml_min_areas_200m
# - kml_std_height_roof_150m
# - kml_min_height_roof_150m
# - kml_min_areas_150m
# - kml_max_height_roof_50m
# - kml_max_height_per_squared_meter_800m
# - kml_min_height_per_squared_meter_700m
# - kml_mean_height_roof_50m
# - kml_mean_height_roof_100m
# - sntnl_std_mbi_50m
# - kml_mean_areas_150m
# - kml_min_height_per_squared_meter_500m
# - kml_max_height_per_squared_meter_600m
# - kml_min_height_per_squared_meter_450m
# - kml_mean_height_roof_150m
# - kml_min_height_per_squared_meter_150m
# - kml_max_height_per_squared_meter_700m
# - kml_min_height_per_squared_meter_400m
# - kml_min_height_per_squared_meter_300m
# - kml_min_height_per_squared_meter_200m
# - kml_min_height_per_squared_meter_275m
# - kml_min_height_per_squared_meter_250m
# - kml_min_height_per_squared_meter_350m

# %%
# -----------------------------------------------------------------------------
# RFECV with RandomForest
# -----------------------------------------------------------------------------

from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

rfe_fs = RFECV(estimator=ExtraTreesRegressor(random_state=SEED),    # RandomForestRegressor(oob_score=True, random_state=SEED), 
               cv=KFold(n_splits=10, shuffle=True, random_state=SEED), 
               scoring='r2', step=2, n_jobs=-1, verbose=1)
X_selected = rfe_fs.fit_transform(X, y)

print(f"{rfe_fs.ranking_=}")
try:
    print(f"{rfe_fs.cv_results_.keys()=}")
    idxmx = np.argmax(rfe_fs.cv_results_['mean_test_score'])
    print(f" -> {rfe_fs.cv_results_['mean_test_score'][idxmx]} +/- {rfe_fs.cv_results_['std_test_score'][idxmx]}")
    print(f"Best number of features: {rfe_fs.cv_results_['n_features'][idxmx]}")

    plt.figure()
    # plt.plot(rfe_fs.cv_results_['n_features'][2:], rfe_fs.cv_results_['mean_test_score'][2:], color='blue')
    plt.errorbar(
        x=rfe_fs.cv_results_["n_features"][2:],
        y=rfe_fs.cv_results_["mean_test_score"][2:],
        yerr=rfe_fs.cv_results_["std_test_score"][2:],
    )
    # plt.xscale('log')
    # plt.yscale('log')
    plt.xlabel('Number of Features Selected')
    plt.ylabel('Cross-Validation Score (R2)')
    plt.title('RFECV - Number of Features vs. Cross-Validation Score')
    plt.show()
except:
    pass

X_rfe = X.loc[:, rfe_fs.support_]

print(X_selected.var(axis=0))
# display(X_rfe.head())
print(X_rfe.columns)

print(f"After RFECV Feature Selection-> {X_selected.shape[1]=}")
X_rfe.to_parquet('../pipeline/data/processed/train/X_selected.parquet')
pd.DataFrame(y).to_parquet('../pipeline/data/processed/train/y_selected.parquet')
print(f"Saved selected features to parquet files")
# Out:
# Fitting estimator with 142 features.
# Fitting estimator with 142 features.
# Fitting estimator with 142 features.
# Fitting estimator with 142 features.
# Fitting estimator with 142 features.
# Fitting estimator with 142 features.
# Fitting estimator with 142 features.
# Fitting estimator with 142 features.
# Fitting estimator with 142 features.
# Fitting estimator with 142 features.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       6 from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
#       8 rfe_fs = RFECV(estimator=ExtraTreesRegressor(random_state=SEED),    # RandomForestRegressor(oob_score=True, random_state=SEED),
#       9                cv=KFold(n_splits=10, shuffle=True, random_state=SEED),
#      10                scoring='r2', step=2, n_jobs=-1, verbose=1)
# ---> 11 X_selected = rfe_fs.fit_transform(X, y)
#      13 print(f"{rfe_fs.ranking_=}")
#      14 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/_set_output.py:295, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     293 @wraps(f)
#     294 def wrapped(self, X, *args, **kwargs):
# --> 295     data_to_wrap = f(self, X, *args, **kwargs)
#     296     if isinstance(data_to_wrap, tuple):
#     297         # only wrap the first output for cross decomposition
#     298         return_tuple = (
#     299             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     300             *data_to_wrap[1:],
#     301         )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:1101, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#    1098     return self.fit(X, **fit_params).transform(X)
#    1099 else:
#    1100     # fit method of arity 2 (supervised transformation)
# -> 1101     return self.fit(X, y, **fit_params).transform(X)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/feature_selection/_rfe.py:752, in RFECV.fit(self, X, y, groups)
#     749     parallel = Parallel(n_jobs=self.n_jobs)
#     750     func = delayed(_rfe_single_fit)
# --> 752 scores = parallel(
#     753     func(rfe, self.estimator, X, y, train, test, scorer)
#     754     for train, test in cv.split(X, y, groups)
#     755 )
#     757 scores = np.array(scores)
#     758 scores_sum = np.sum(scores, axis=0)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:
